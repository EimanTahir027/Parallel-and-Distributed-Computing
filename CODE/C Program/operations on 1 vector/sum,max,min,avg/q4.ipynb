# %%
# %%writefile q4.c
#
# #include <stdio.h>
# #include <stdlib.h>
# #include <time.h>
#
# #define N    60
# #define LOW  10
# #define HIGH 99
#
# int   vecSum(int* hA, int n);
# int   vecMax(int* hA, int n);
# int   vecMin(int* hA, int n);
# float vecAvg(int* hA, int n);
# void  printVec(const char* label, int* v, int n);
#
# int main()
# {
#     int   *hA;
#     int    hSum, hMax, hMin;
#     float  hAvg;
#
#     hA = (int*) malloc(N * sizeof(int));
#
#     srand(time(NULL));              /* seed once, OUTSIDE loop */
#     for(int i=0; i<N; i++)         /* ; not , */
#     {
#         hA[i] = rand()%90+10;      /* rand() not srand(), no *, hA not h_A */
#     }                              /* hB removed — Q4 only uses hA */
#
#     printVec("hA", hA, N);
#
#     hSum = vecSum(hA, N);
#     hMax = vecMax(hA, N);
#     hMin = vecMin(hA, N);
#     hAvg = vecAvg(hA, N);
#
#     printf("\nSum  (hSum) = %d\n",   hSum);
#     printf("Max  (hMax) = %d\n",   hMax);
#     printf("Min  (hMin) = %d\n",   hMin);
#     printf("Avg  (hAvg) = %.2f\n", hAvg);
#
#     free(hA);
#     return 0;
# }
#
# int vecSum(int* hA, int n)
# {
#     int hSum = 0;
#     for(int i=0; i<n; i++)
#         hSum +=
# Out:
# Overwriting q4.c

# %%
# !gcc q3.c -o q3

# %%
# !./q4
# Out:
# hA:
#   12  14  44  97  61  56  46  91  81  52  97  36  70  14  87  42  20  55  73  83  70  72  37  47  38  80  13  94  48  30  96  12  34  41  61  47  49  97  39  30  11  88  57  33  54  44  28  64  51  91  48  21  25  37  58  16  17  23  10  17
#
# Sum  (hSum) = 2959
# Max  (hMax) = 97
# Min  (hMin) = 10
# Avg  (hAvg) = 49.32
